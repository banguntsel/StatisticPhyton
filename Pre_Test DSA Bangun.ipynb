# %% [markdown]
# # Pre Test
# Source of Data set about google play store is from :
# <br>[https://www.openml.org/d/40701]
# <br>Copy the data set from
# <br>[https://raw.githubusercontent.com/banguntsel/HomeworkPhyton/master/googleplaystore.csv]
#
# *<p>Author  : Bangun M Sagala*
# *<p>Date    : 16 October 2019*
# ***

# %%
import pandas as pd
import numpy as np
import statistics as stat

# %%
df = pd.read_csv('https://raw.githubusercontent.com/banguntsel/HomeworkPhyton/master/churn.csv', encoding='latin1')

# %%
df.head()
# Out:
#    state  account_length  area_code  phone_number  international_plan  \
# 0     16             128        415          2845                   0
# 1     35             107        415          2301                   0
# 2     31             137        415          1616                   0
# 3     35              84        408          2510                   1
# 4     36              75        415           155                   1
#
#    voice_mail_plan  number_vmail_messages  total_day_minutes  total_day_calls  \
# 0                1                     25              265.1              110
# 1                1                     26              161.6              123
# 2                0                      0              243.4              114
# 3                0                      0              299.4               71
# 4                0                      0              166.7              113
#
#    total_day_charge  ...  total_eve_calls  total_eve_charge  \
# ...

# %%
df.shape
# Out:
# (5000, 21)

# %% [markdown]
# ### 1. Which has state has the highest churn customer ?
# <p> The Answer is state number 49

# %%
df['state'].value_counts().head(5)
# Out:
# 49    158
# 23    125
# 1     124
# 13    119
# 45    118
# Name: state, dtype: int64

# %% [markdown]
# ### 2. What is the connection between total customer churn and total call to customer service
# <p> The Answer : The state number  49 is the greatest total number customer churn with also the greatest number of total call to customer service, means many complain in 49 state so the customer churn

# %%
    state_complain=df.groupby('state')['number_customer_service_calls'].sum()
    state_complain=state_complain.sort_values(ascending=False)
    state_complain.head(5)
# Out:
# state
# 49    259
# 13    205
# 34    197
# 37    194
# 31    194
# Name: number_customer_service_calls, dtype: int64

# %% [markdown]
# ### 3. What is the connection between total customer churn and total charge
# <p> Customers who are churn in state 49 generate the highest revenue from total state

# %%
state_charge=df.groupby('state')['total_day_charge'].sum()
state_charge=state_charge.sort_values(ascending=False)
state_charge.head(5)
# Out:
# state
# 49    4754.86
# 1     3994.15
# 23    3881.04
# 13    3688.39
# 35    3662.64
# Name: total_day_charge, dtype: float64

# %% [markdown]
# ### 4. What is the connection between total customer churn and total charge
# <p> state with high churn corelated with high night call

# %%
state_night=df.groupby('state')['total_night_calls'].sum()
state_night=state_charge.sort_values(ascending=False)
state_night.head(5)
# Out:
# state
# 49    4754.86
# 1     3994.15
# 23    3881.04
# 13    3688.39
# 35    3662.64
# Name: total_day_charge, dtype: float64

# %% [markdown]
# ### 5. Correlation between variable using Pearson
# Corelation with Pearson methode with all the variable in dataframe

# %%
df.corr(method='pearson')
# Out:
#                                   state  account_length  area_code  \
# state                          1.000000        0.010334   0.013858
# account_length                 0.010334        1.000000  -0.018054
# area_code                      0.013858       -0.018054   1.000000
# phone_number                   0.017054        0.004918  -0.011648
# international_plan             0.007422        0.014681   0.032107
# voice_mail_plan               -0.030075       -0.006650  -0.003006
# number_vmail_messages         -0.027282       -0.014575  -0.003399
# total_day_minutes              0.007334       -0.001017  -0.019118
# total_day_calls               -0.008166        0.028240  -0.019314
# total_day_charge               0.007334       -0.001019  -0.019119
# total_eve_minutes              0.003900       -0.009591   0.007098
# total_eve_calls               -0.005458        0.009143  -0.012300
# total_eve_charge               0.003896       -0.009587   0.007114
# ...
